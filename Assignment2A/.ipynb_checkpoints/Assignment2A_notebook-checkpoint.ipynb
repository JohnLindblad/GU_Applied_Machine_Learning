# %% [markdown]
# # Assignment 2A - Part 3: Implementing the classifier

# %% [markdown]
# by John Lindblad and Olle Lindgren

# %% [markdown]
# ## Importing packages and data

# %%
# standard tools and text preprocessing
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.pipeline import make_pipeline
# model evaluation
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import plot_confusion_matrix
# classifiers
from sklearn.svm import LinearSVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

# %%
# importing the data
training_data = pd.read_csv('a2a_train_round1.tsv', sep='\t', header=None)
Y = training_data[0]
X = training_data[1]
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state=0)

# %% [markdown]
# ## Comparing a couple of potential classifiers

# %%
def train_document_classifier(X,Y, classifier):
    pipeline = make_pipeline( TfidfVectorizer(), classifier)
    pipeline.fit(X,Y)
    return pipeline

# %%
def compare_classifiers(clf_list, X_train, Y_train, X_test, Y_test):
    for c in clf_list:
        m_name = type(c).__name__
        clf =  train_document_classifier(X_train, Y_train, c)
        accuracy = accuracy_score(Y_test, clf.predict(X_test))
        print(f'The accuracy of {m_name} on the test set is: {accuracy}')
        plot_confusion_matrix(clf, X_test, Y_test, normalize='all')
        plt.title(m_name)
    return None

# %%
# comparing a couple of classifiers
clf_list = [LinearSVC(random_state=0), DecisionTreeClassifier(random_state=0), RandomForestClassifier(n_jobs=-1, random_state=0)]
compare_classifiers(clf_list, X_train, Y_train, X_test, Y_test)
# Out:
# The accuracy of LinearSVC on the test set is: 0.7200383509108341
# The accuracy of DecisionTreeClassifier on the test set is: 0.6279961649089166
# The accuracy of RandomForestClassifier on the test set is: 0.7070949185043145

# %% [markdown]
# ## Going further with the selected classifier
